# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
moviesdata = pd.read_excel('vgsales.xlsx')
moviesdata
# Out:
#         Rank               Name Platform    Year     Genre Publisher  \
# 0          1         Wii Sports      Wii  2006.0    Sports  Nintendo
# 1          1         Wii Sports      Wii  2006.0    Sports  Nintendo
# 2          1         Wii Sports      Wii  2006.0    Sports  Nintendo
# 3          1         Wii Sports      Wii  2006.0    Sports  Nintendo
# 4          2  Super Mario Bros.      NES  1985.0  Platform  Nintendo
# ...      ...                ...      ...     ...       ...       ...
# 66387  16599         Know How 2       DS  2010.0    Puzzle  7G//AMES
# 66388  16600   Spirits & Spells      GBA  2003.0  Platform   Wanadoo
# 66389  16600   Spirits & Spells      GBA  2003.0  Platform   Wanadoo
# 66390  16600   Spirits & Spells      GBA  2003.0  Platform   Wanadoo
# 66391  16600   Spirits & Spells      GBA  2003.0  Platform   Wanadoo
#
#          SalesType  Value
# 0         NA_Sales  41.49
# 1         EU_Sales  29.02
# 2         JP_Sales   3.77
# 3      Other_Sales   8.46
# ...

# %%
topxmovies = moviesdata.loc[((moviesdata['Rank'] >=1)&(moviesdata['Rank']<=5))]
topxmovies
# Out:
#     Rank                      Name Platform    Year         Genre Publisher  \
# 0      1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1      1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 2      1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 3      1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 4      2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 5      2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 6      2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 7      2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 8      3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 9      3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 10     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# ...

# %%
fig_dims = (15, 10)
fig, ax = plt.subplots(figsize=fig_dims)
sns.barplot(x = 'Name', y = 'Value', data = topxmovies, hue = 'SalesType', ax=ax)
# Out:
# <AxesSubplot:xlabel='Name', ylabel='Value'>
